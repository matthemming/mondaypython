# %%
import pyodbc
import pandas as pd 
import requests
import geocoder
from geopy.geocoders import Nominatim
from IPython.display import clear_output
from pprint import pprint
import time
import re
import timeit
from IPython.display import clear_output

# %%
cnxn = pyodbc.connect('DSN=SQLAmlin;UID=MSAmlin;PWD=password')

# %%
cur = cnxn.cursor()

# %% [markdown]
# ### Define function for getting address parts

# %%
def get_full_address(part_addr):
    '''Takes an address and returns a dictionary containing the components of the address.
    Works best with a road name and town'''
    time.sleep(1)
    # This outer try/except block ensures that a dictionary of the 
    # correct form is returned if the geocoder bit doesn't work
    # so that key errors won't stop this from being applied to a dataframe column
    try:
        addr_dict = {}
        
        g = geocoder.osm(part_addr)
        try:
            addr_dict['HouseNumber'] = g.json['raw']['address']['house_number'] 
        except KeyError:
            addr_dict['HouseNumber'] = None
        
        try:
            addr_dict['Road'] = g.json['raw']['address']['road']
        except KeyError:
            addr_dict['Road'] = None
        
        # The 'town' bit of the address is sometimes stored under different keys in the json
        try:
            addr_dict['Town'] = g.json['raw']['address']['town']
        except KeyError:
            try:
                addr_dict['Town'] = g.json['raw']['address']['suburb']
            except KeyError:
                try:
                    addr_dict['Town'] = g.json['raw']['address']['city']
                except:
                    addr_dict['Town'] = None
        
        try:
            addr_dict['Postcode'] = g.json['raw']['address']['postcode']
        except KeyError:
            addr_dict['Postcode'] = None
            
        try:
            addr_dict['Lat'] = g.json['lat']
        except KeyError:
            addr_dict['Lat'] = None
        
        try:
            addr_dict['Long'] = g.json['lng']
        except KeyError:
            addr_dict['Long'] = None
        
        return addr_dict    
    
    # If geocoder lookup doesn't work then return a dictionary of 'location not found' to differentiate between the None values 
    except:
        return {'HouseNumber': 'Location not found', 'Road': 'Location not found', 'Town': 'Location not found', 'Postcode': 'Location not found', 'Lat': 'Location not found', 'Long': 'Location not found'}

# %% [markdown]
# ### Cambridgeshire Geocoding

# %%
cambs_query = 'select * from initial.CambridgeshireFire'

# %%
cambs_df = pd.read_sql(cambs_query, cnxn)

# %%
# get rid of weird characters
cambs_df['title'] = cambs_df['title'].map(lambda x: x.replace('â€“', '-'))
# incident type stored with address - split on ' - ' to separate, then drop the first list item, then join to connect elements of address
cambs_df['location'] = cambs_df['title'].map(lambda x: ', '.join(x.split(' - ')[1:]))
# when locations have only 1 word, put cambridgeshire in the address to increase chance of OSM finding the right one
cambs_df['location'] = cambs_df['location'].map(lambda x: x + ', Cambridgeshire' if (x.count(', ') == 0)  else x)

# %%
# Geocoding using get_full_address function run on the cleaned location column

cambs_df['AddressDict'] = cambs_df['location'].map(lambda x: get_full_address(x))

cambs_df['HouseNumber'] = cambs_df['AddressDict'].map(lambda x: x['HouseNumber'])
cambs_df['Road'] = cambs_df['AddressDict'].map(lambda x: x['Road'])
cambs_df['Town'] = cambs_df['AddressDict'].map(lambda x: x['Town'])
cambs_df['Postcode'] = cambs_df['AddressDict'].map(lambda x: x['Postcode'])
cambs_df['Lat'] = cambs_df['AddressDict'].map(lambda x: x['Lat'])
cambs_df['Long'] = cambs_df['AddressDict'].map(lambda x: x['Long'])

# %%
# No postcodes or LatLongs were in the original data so all flagged as inferred
cambs_df['PostcodeInferredFlag'] = 1
cambs_df['LatLongInferredFlag'] = 1

# %%
(cambs_df.shape[0]-cambs_df[cambs_df['HouseNumber'] == 'Location not found'].shape[0])/cambs_df.shape[0]
# Out:
# 0.9742813918305597

# %%
cambs_df.to_csv(r'C:\git\fire\area\LocationsAfterGeocoding\CambridgeshireGeocoded.csv', index=False)

# %% [markdown]
# ### Cornwall Geocoding

# %%
corn_query = 'select * from initial.Cornwall'

# %%
corn_df = pd.read_sql(corn_query, cnxn)

# %%
corn_df['location'] = corn_df['location'].fillna('')
corn_df['location'] = corn_df['location'].map(lambda x: x.replace('near', ''))

# %%
# Geocoding using get_full_address function run on the cleaned location column

corn_df['AddressDict'] = corn_df['location'].map(lambda x: get_full_address(x))

corn_df['HouseNumber'] = corn_df['AddressDict'].map(lambda x: x['HouseNumber'])
corn_df['Road'] = corn_df['AddressDict'].map(lambda x: x['Road'])
corn_df['Town'] = corn_df['AddressDict'].map(lambda x: x['Town'])
corn_df['Postcode'] = corn_df['AddressDict'].map(lambda x: x['Postcode'])
corn_df['Lat'] = corn_df['AddressDict'].map(lambda x: x['Lat'])
corn_df['Long'] = corn_df['AddressDict'].map(lambda x: x['Long'])

# %%
(corn_df.shape[0]-corn_df[corn_df['HouseNumber'] == 'Location not found'].shape[0])/corn_df.shape[0]
# Out:
# 0.6961248954558127

# %%
# No postcodes or LatLongs were in the original data so all flagged as inferred
corn_df['PostcodeInferredFlag'] = 1
corn_df['LatLongInferredFlag'] = 1

# %%
corn_df.to_csv(r'C:\git\fire\area\LocationsAfterGeocoding\CornwallGeocoded.csv', index=False)

# %% [markdown]
# ### Cumbria Geocoding

# %%
cumb_query = 'select * from initial.Cumbria'

# %%
cumb_df = pd.read_sql(cumb_query, cnxn)

# %%
cumb_df['location'] = cumb_df['location'].map(lambda x: x[1:-1] + ', Cumbria')

# %%
cumb_df['AddressDict'] = cumb_df['location'].map(lambda x: get_full_address(x))

cumb_df['HouseNumber'] = cumb_df['AddressDict'].map(lambda x: x['HouseNumber'])
cumb_df['Road'] = cumb_df['AddressDict'].map(lambda x: x['Road'])
cumb_df['Town'] = cumb_df['AddressDict'].map(lambda x: x['Town'])
cumb_df['Postcode'] = cumb_df['AddressDict'].map(lambda x: x['Postcode'])
cumb_df['Lat'] = cumb_df['AddressDict'].map(lambda x: x['Lat'])
cumb_df['Long'] = cumb_df['AddressDict'].map(lambda x: x['Long'])

# %%
(cumb_df.shape[0]-cumb_df[cumb_df['HouseNumber'] == 'Location not found'].shape[0])/cumb_df.shape[0]
# Out:
# 1.0

# %%
# No postcodes or LatLongs were in the original data so all flagged as inferred
cumb_df['PostcodeInferredFlag'] = 1
cumb_df['LatLongInferredFlag'] = 1

# %%
cumb_df.to_csv(r'C:\git\fire\area\LocationsAfterGeocoding\CumbriaGeocoded.csv', index=False)

# %% [markdown]
# ### Devon Geocoding

# %%
dev_query = 'select * from [initial].[Devon]'

# %%
dev_df = pd.read_sql(dev_query, cnxn)

# %%
dev_df
# Out:
#        IncidentID     id                                              Title  \
# 0               1  10000                               Incident - Shed fire
# 1               2  10011                         Incident - Fire in Factory
# 2               3  10015                            Incident - Chimney Fire
# 3               4  10023                            Incident - Kitchen fire
# 4               5  10028                        Incident - Dining room fire
# 5               6  10032                 Incident - Shed / Green house fire
# 6               7  10034                           Incident - Building fire
# 7               8  10035                            Incident - Kitchen Fire
# 8               9  10036                            Incident - Kitchen fire
# 9              10  10041                           Incident - Bin Shed Fire
# 10             11  10044                               Incident - Barn Fire
# 11             12  10046                         Incident - Fire - building
# 12             13  10049            Incident - Property Fire - Final update
# 13             14  10051                           Incident - Hay Barn Fire
# 14             15  10052                               Incident - Barn Fire
# 15             16  10054                            Incident - Kitchen Fire
# 16             17  10060                            Incident - Bedroom Fire
# 17             18  10061                            Incident - Kitchen Fire
# 18             19  10063                            Incident - Bedroom Fire
# 19             20  10069                            Incident - Kitchen Fire
# 20             21  10071                               Incident - Flat Fire
# 21             22  10078             Incident - Fire in Recycling Container
# 22             23  10084                  Incident - Fire in public Toilets
# 23             24  10085                           Incident - Kitchen Fire.
# 24             25   1009                       Incident - Fish Shed on Fire
# 25             26  10095                            Incident - Kitchen fire
# 26             27  10104                    Incident - Small Fire In Church
# 27             28  10117                              Incident - House Fire
# 28             29  10118                           Incident - Property Fire
# 29             30  10120                               Incident - Barn fire
# ...           ...    ...                                                ...
# 13274       13275   9863                           Incident - Building Fire
# 13275       13276   9872                              Incident - House Fire
# 13276       13277   9873                            Incident - Kitchen Fire
# 13277       13278   9876                            Incident - Kitchen Fire
# 13278       13279   9881                            Incident - Kitchen fire
# 13279       13280   9889                               Incident - Flat Fire
# 13280       13281   9890                              Incident - House Fire
# 13281       13282   9896                            Incident - Kitchen Fire
# 13282       13283   9897                           Incident - Property Fire
# 13283       13284    990                            Incident - Kitchen Fire
# 13284       13285   9913                            Incident - Kitchen Fire
# 13285       13286   9914                             Incident - Garage Fire
# 13286       13287   9917                            Incident - Kitchen Fire
# 13287       13288   9919                            Incident - Kitchen Fire
# 13288       13289    992                            Incident - Kitchen Fire
# 13289       13290   9929                               Incident - Flat Fire
# 13290       13291   9935                 Incident - Fire in 2nd Floor Flat.
# 13291       13292   9939                               Incident - Shed Fire
# 13292       13293   9948                            Incident - Factory Fire
# 13293       13294   9960                 Incident - Bin on fire near garage
# 13294       13295   9964  Incident - Fire involving Cardboard Recycling ...
# 13295       13296   9968                         Incident - Fire - Building
# 13296       13297   9969                            Incident - Kitchen Fire
# 13297       13298   9973                           Incident - Fire Building
# 13298       13299   9974                         Incident - Fire - Building
# 13299       13300   9975                         Incident - Fire - Building
# 13300       13301   9979                         Incident - Fire in bedroom
# 13301       13302   9993                            Incident - Kitchen Fire
# 13302       13303   9994                           Incident - Workshop fire
# 13303       13304   9997         Incident - Kitchen fire involving toaster.
#
#              Date   Time                                           Location  \
# 0      09/07/2009  12:30      Church Street, Morchard Bishop near Crediton.
# 1      10/07/2009  10:48  Industrial Factory, Heron Road,Sowton Industri...
# 2      10/07/2009  22:42                              Broadbury, Okehampton
# 3      11/07/2009  09:10                          St Thomas Close, Plympton
# 4      11/07/2009  16:08                             Upland Drive, Plymouth
# 23     Devon Fire Control received a call about a Fir...
# 24     The Fire Service were called to a report of a ...
# 25     Two fire appliances from Barnstaple attended a...
# 26     At 11.19am fire control received a call report...
# 27     One appliance from Holsworthy and two from Lau...
# 28     At 2153hrs the Fire Service mobilised 2 fire a...
# 29     Fire crews from across North Devon are attendi...
# ...                                                  ...
# 13274  Two Fire Appliances attended the report of a b...
# 13275  Two fire appliances from Topsham with Watch Co...
# 13276  Two fire appliances from Bideford attended sou...
# 13277  The Fire Service received a call from Torbay L...
# 13278  The Fire Service received a call to a kitchen ...
# 13279  Two fire engines from Paignton with watch mana...
# 13280  Two fire appliances from Torquay attended lyme...
# 13281  Two fire appliances from Torquay attended the ...
# 13282  Multiple numbers of calls were received report...
# 13283  Two appliances from Camels Head attended a rep...
# 13284  Two Fire Engines from Burnham on Sea, were mob...
# 13285  Two fire appliances from Plymstock and Modbury...
# 13286  The Fire Service received a call to a fire in ...
# 13287  The Fire Service received a call to a kitchen ...
# 13288  The Fire Service were called to reports of a c...
# 13289  The Fire Service received a call to a fire wit...
# 13290  A telephone call was received in Devon Fire Co...
# 13291  One Appliance from Paignton with Watch Command...
# 13292  The Fire Service was called to a report of smo...
# 13293  One appliance from Appledore was mobilised to ...
# 13294  Devon Fire Control received a report of a fire...
# 13295  Devon Fire Control received a report of smoke ...
# 13296  The Fire Service was called to a report ofÂ a ...
# 13297  Devon Fire Control received a report of a fire...
# 13298  Devon Fire Control has received numerous repor...
# 13299  Devon Fire Control received a report of a fire...
# 13300  Two fire engines from Crownhill and Camels Hea...
# 13301  The Fire Service received a call to a fire wit...
# 13302  The Fire Service received a call to a workshop...
# 13303  Devon Fire Control received a call reporting a...
#
# [13304 rows x 9 columns]

# %%
# not run yet, will take ~4 hours
dev_df['AddressDict'] = dev_df['Location'].map(lambda x: get_full_address(x))

dev_df['HouseNumber'] = dev_df['AddressDict'].map(lambda x: x['HouseNumber'])
dev_df['Road'] = dev_df['AddressDict'].map(lambda x: x['Road'])
dev_df['Town'] = dev_df['AddressDict'].map(lambda x: x['Town'])
dev_df['Postcode'] = dev_df['AddressDict'].map(lambda x: x['Postcode'])
dev_df['Lat'] = dev_df['AddressDict'].map(lambda x: x['Lat'])
dev_df['Long'] = dev_df['AddressDict'].map(lambda x: x['Long'])

# %%
(dev_df.shape[0]-dev_df[dev_df['HouseNumber'] == 'Location not found'].shape[0])/dev_df.shape[0]

# %%
# No postcodes or LatLongs were in the original data so all flagged as inferred
dev_df['PostcodeInferredFlag'] = 1
dev_df['LatLongInferredFlag'] = 1

# %%
dev_df.to_csv(r'C:\git\fire\area\LocationsAfterGeocoding\DevonGeocoded.csv', index=False)

# %% [markdown]
# ### Essex Geocoding

# %%
essex_query = 'select * from [initial].[Essex]'

# %%
essex_df = pd.read_sql(essex_query, cnxn)

# %%
essex_df['AddressDict'] = essex_df['Location'].map(lambda x: get_full_address(x))

essex_df['HouseNumber'] = essex_df['AddressDict'].map(lambda x: x['HouseNumber'])
essex_df['Road'] = essex_df['AddressDict'].map(lambda x: x['Road'])
essex_df['Town'] = essex_df['AddressDict'].map(lambda x: x['Town'])
essex_df['Postcode'] = essex_df['AddressDict'].map(lambda x: x['Postcode'])
essex_df['Lat'] = essex_df['AddressDict'].map(lambda x: x['Lat'])
essex_df['Long'] = essex_df['AddressDict'].map(lambda x: x['Long'])

# %%
(essex_df.shape[0]-essex_df[essex_df['HouseNumber'] == 'Location not found'].shape[0])/essex_df.shape[0]
# Out:
# 0.9382504288164666

# %%
# No postcodes or LatLongs were in the original data so all flagged as inferred
essex_df['PostcodeInferredFlag'] = 1
essex_df['LatLongInferredFlag'] = 1

# %%
essex_df.to_csv(r'C:\git\fire\area\LocationsAfterGeocoding\EssexGeocoded.csv', index=False)

# %% [markdown]
# ### Hampshire Geocoding

# %%
# This isn't performing as well as it should -  sometimes when there's a postcode in the address it's confusing OSM - maybe won't happen with OpenCage

# %%
hamp_query = 'select * from [initial].[Hampshire]'

# %%
hamp_df = pd.read_sql(hamp_query, cnxn)

# %%
hamp_df['Address'] = hamp_df['Address'].fillna('None')
hamp_df['Address'] = hamp_df['Address'].map(lambda x: x.replace('<div class="addressDisplay">', '').replace('</div>', '').replace('---', ' ').strip())

# %%
hamp_df['AddressDict'] = hamp_df['Address'].map(lambda x: get_full_address(x))

hamp_df['HouseNumber'] = hamp_df['AddressDict'].map(lambda x: x['HouseNumber'])
hamp_df['Road'] = hamp_df['AddressDict'].map(lambda x: x['Road'])
hamp_df['Town'] = hamp_df['AddressDict'].map(lambda x: x['Town'])
hamp_df['Postcode'] = hamp_df['AddressDict'].map(lambda x: x['Postcode'])
hamp_df['Lat'] = hamp_df['AddressDict'].map(lambda x: x['Lat'])
hamp_df['Long'] = hamp_df['AddressDict'].map(lambda x: x['Long'])

# %%
(hamp_df.shape[0]-hamp_df[hamp_df['HouseNumber'] == 'Location not found'].shape[0])/hamp_df.shape[0]
# Out:
# 0.6346820809248555

# %%
hamp_df['PostcodeInferredFlag'] = 0
hamp_df['PostcodeInferredFlag'] = 0
hamp_df.loc[hamp_df['Postcode'] in hamp_df['Address'], essex_df['PostcodeInferredFlag']] = 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-209-2fb24bf3f661> in <module>()
#       1 hamp_df['PostcodeInferredFlag'] = 0
# ----> 2 hamp_df.loc[hamp_df['Postcode'] in hamp_df['Address'], essex_df['PostcodeInferredFlag']] = 1
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __contains__(self, key)
#    1520     def __contains__(self, key):
#    1521         """True if the key is in the info axis"""
# -> 1522         return key in self._info_axis
#    1523
#    1524     @property
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in __contains__(self, key)
#    2033     @Appender(_index_shared_docs['__contains__'] % _index_doc_kwargs)
#    2034     def __contains__(self, key):
# -> 2035         hash(key)
#    2036         try:
#    2037             return key in self._engine
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __hash__(self)
#    1490     def __hash__(self):
#    1491         raise TypeError('{0!r} objects are mutable, thus they cannot be'
# -> 1492                         ' hashed'.format(self.__class__.__name__))
#    1493
#    1494     def __iter__(self):
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed

# %%
hamp_df.iloc[7]['Postcode'] in hamp_df.iloc[7]['Address']
# Out:
# True

# %%
df.loc[df['c1'] == 'Value', 'c2']

# %%
hamp_df
# Out:
#      IncidentID         Post Date  \
# 0             1  01/01/2014 21:21
# 1             2  01/04/2014 21:55
# 2             3  01/04/2016 12:07
# 3             4  01/04/2018 12:54
# 4             5  01/06/2016 22:51
# 5             6  01/07/2014 12:40
# 6             7  01/07/2014 19:17
# 7             8  01/07/2017 15:30
# 8             9  01/07/2018 03:35
# 9            10  01/08/2015 18:15
# 10           11  01/08/2016 21:11
# 11           12  01/09/2016 02:24
# 12           13  01/10/2014 19:22
# 13           14  01/11/2016 20:48
# 14           15  01/12/2013 10:37
# 15           16  01/12/2013 14:37
# 16           17  01/12/2013 20:24
# 17           18  01/12/2013 21:22
# 18           19  01/12/2013 21:36
# 19           20  01/12/2015 21:20
# 20           21  02/01/2014 18:40
# 21           22  02/01/2017 00:45
# 22           23  02/04/2014 13:32
# 23           24  02/04/2017 18:12
# 24           25  02/05/2014 01:13
# 25           26  02/05/2017 13:40
# 26           27  02/06/2015 04:24
# 27           28  02/06/2015 21:40
# 28           29  02/06/2015 22:21
# 29           30  02/06/2016 20:23
# ..          ...               ...
# 835         836  30/07/2014 09:43
# 836         837  30/08/2014 18:06
# 837         838  30/08/2015 21:55
# 838         839  30/09/2013 11:17
# 839         840  30/09/2013 17:48
# 840         841  30/09/2014 02:59
# 841         842  30/09/2014 16:20
# 842         843  30/10/2016 20:08
# 843         844  30/11/2014 04:14
# 844         845  30/11/2014 18:16
# 845         846  30/11/2015 03:36
# 846         847  30/11/2015 15:47
# 847         848  30/11/2017 15:57
# 848         849  30/12/2014 00:23
# 849         850  31/01/2014 01:33
# 850         851  31/01/2014 04:10
# 851         852  31/01/2018 03:00
# 852         853  31/03/2015 21:51
# 853         854  31/05/2014 03:41
# 854         855  31/05/2015 10:51
# 855         856  31/07/2015 15:10
# 856         857  31/07/2016 08:38
# 857         858  31/10/2013 20:26
# 858         859  31/10/2015 03:00
# 859         860  31/10/2015 19:11
# 860         861  31/10/2015 19:41
# 861         862  31/10/2016 15:06
# 862         863  31/10/2017 20:08
# 863         864  31/10/2018 20:04
# 864         865  31/12/2016 17:11
#
#                                                  Title  \
# 0                                                 Fire
# 1                                                 Fire
# 2                                Fire - Hayling Island
# 3    Crews tackle bin chute fire at Portsmouth high...
# 4                               Fire Domestic - Havant
# 5                                                 Fire
# 6                                                 Fire
# 7    Gym, workshop and garden centre damaged in Whi...
# 8            Cigarette causes Southampton balcony fire
# 9                                      Fire - Beaulieu
# 10                              Domestic Fire - Romsey
# 11           Fire in derelict building - Waterlooville
# 12                                                Fire
# 13                      Residential fire - Southampton
# 14                                                Fire
# 15                                                Fire
# 16                                                Fire
# 17                                                Fire
# 18                                                Fire
# 19                                   Fire - Portsmouth
# 20                                                Fire
# 21                                       Fire - Havant
# 22                                                Fire
# 23                         Thatched roof fire - Romsey
# 24                                                Fire
# 25                                High-rise - Gunwharf
# 26                               Fire - Milford on Sea
# 27                                   Fire - New Milton
# 28                              Gas leak - Otterbourne
# 29                                  Fire - Basingstoke
# ..                                                 ...
# 835                                               Fire
# 836                                               Fire
# 837                                      Fire - Cosham
# 838                                               Fire
# 839                                               Fire
# 840                                               Fire
# 841                                               Fire
# 842                                 Fire - Southampton
# 843                                               Fire
# 844                                               Fire
# 845                                 Fire - Otterbourne
# 846                               Fire - Waterlooville
# 847       Over 50 firefighters tackle thatch roof fire
# 848                                     Fire - Headley
# 849                                               Fire
# 850                                               Fire
# 851  Commercial garage fire tackled by Eastleigh crews
# 852                                   Fire - Aldershot
# 853                                               Fire
# 854                                   Fire - Hedge End
# 855                        Aircraft Crashed, Camberley
# 856                                      Fire - Hilsea
# 857                                               Fire
# 858                                      Fire Domestic
# 859                                 Fire - Basingstoke
# 860                               Fire - Lee on Solent
# 861                       Residential fire - Eastleigh
# 862             Firework sparks shed fire in Camberley
# 863  Booby-trapped blaze set by arsonists endangeri...
# 864                      Commercial fire - Southampton
#
#                                          Incident Text  \
# 0    Around 38 firefighters from Hightown, Botley, ...
# 1    Firefighters have this evening dealt with a sm...
# 2    Firefighters from Hayling Island, Havant, Emsw...
# 3    Crews from Southsea, Cosham, Portchester, Fare...
# 4    Two crews from Havant and one from Cosham atte...
# 5    Around 14 firefighters attended a fire in a gr...
# 6    9 Firefighters from Southsea fire station exti...
# 7    About 30 firefighters battled a blaze after a ...
# 8    Five engines, an aerial ladder platform and su...
# 9    Around six firefighters from Lyndhurst extingu...
# 10   Two crews from Romsey attended a microwave fir...
# 11   We attended an incident at a derelict three st...
# 12   Fire fighters were called to kitchen fire in a...
# 13   Four crews from St Mary's, Hightown and Redbri...
# 14   19 Firefighters from Rushmoor and Farnham (Sur...
# 15   15 firefighters from Hayling Island and Havant...
# 16   We were called to stables on fire - the stable...
# 17   Firefighters attended a caravan and stable fir...
# 18   Firefighters attended a fire involving a track...
# 19   Approximately 20 firefighters from both Souths...
# 20   A total of eight firefighters and one manager ...
# 21   We recieved a 999 call from an elderly lady wh...
# 22   Around 10 firefighter from Winchester and East...
# 23   Crews from St Mary's, Redbridge, Hightown, Eas...
# 24   9 Fire fighters from Hightown Fire Station wer...
# 25   Six crews from across the county attended a se...
# 26   Crews from New Milton were called to reports o...
# 27   Firefighters from New Milton dealt with one ga...
# 28   Firefighters from Eastleigh and Winchester att...
# 29   Crews were called to reports of smoke and flam...
# ..                                                 ...
# 835  Netley Common, SouthamptonÂ Â Crews from Hight...
# 836  A34 Road, Northbound, Litchfield to Tot HillÂ ...
# 837  Crews from Cosham, Havant and Southsea were ca...
# 838  We were called to a vehicle fire on the A31 We...
# 839  Firefighters from Southsea fire station attend...
# 840  Around 15 Firefighters from Andover and Whitch...
# 841  Lodge Road, Portswood, SouthamptonÂ Â Fire in ...
# 842  Crews were called to reports of flames and smo...
# 843  Six firefighters from Gosport fire station ext...
# 844  A3 South between Petersfield and HorndeanÂ Â A...
# 845  Around 51 firefighters were called to a garage...
# 846  Fire Control received calls to a fire in a end...
# 847  Over 50 firefighters responded to a fire in th...
# 848  A total of 16 firefighters attended a boiler f...
# 849  Five crews from Basingstoke were called to a d...
# 850  Five firefighters from Southsea were called to...
# 851  Fire crews were called to a commercial garage ...
# 852  Crews from Rushmoor were called to a fire at V...
# 853  Around eight firefighters from Rushmoor exting...
# 854  Hampshire Fire Service were called to an addre...
# 855  Approximately 24 firefighters from Yateley, Fl...
# 856  Crews making up 6 pumps have been called out t...
# 857  Hampshire Fire and Rescue Service have this ev...
# 855  London Road Blackwater Hampshire GU17 United K...
# 856  Ackworth Road Portsmouth Portsmouth PO3 5NS Un...
# 857  Tower Street Winchester Hampshire SO23 United ...
# 858           Tadley Hampshire RG26 4JX United Kingdom
# 859  Oakridge Road Basingstoke Hampshire RG21 Unite...
# 860  Cockerell Close Lee-on-the-Solent Hampshire PO...
# 861  Harewood Close Eastleigh Hampshire SO50 4NZ Un...
# 862  Woodbridge Road Blackwater Hampshire GU17 0BS ...
# 863  Ashling Park Road Denmead Hampshire PO7 6EH  U...
# 864  West Quay Southampton Southampton SO15 1QB Uni...
#
#                                            AddressDict         HouseNumber  \
# 0    {'HouseNumber': 'Location not found', 'Road': ...  Location not found
# 1    {'HouseNumber': 'Location not found', 'Road': ...  Location not found
# 2    {'HouseNumber': 'Location not found', 'Road': ...  Location not found
# 3    {'HouseNumber': None, 'Road': 'Brownlow Close'...                None
# 4    {'HouseNumber': None, 'Road': 'Soberton Road',...                None
# 5    {'HouseNumber': None, 'Road': 'Shirley High St...                None
# 6    {'HouseNumber': None, 'Road': 'Paignton Avenue...                None
# 7    {'HouseNumber': None, 'Road': 'Church Street',...                None
# 8    {'HouseNumber': None, 'Road': None, 'Town': 'O...                None
# 9    {'HouseNumber': None, 'Road': 'Beaulieu Road',...                None
# 10   {'HouseNumber': None, 'Road': 'Bridge Road', '...                None
# 11   {'HouseNumber': None, 'Road': 'London Road', '...                None
# 12   {'HouseNumber': 'Location not found', 'Road': ...  Location not found
# 13   {'HouseNumber': 'Location not found', 'Road': ...  Location not found
# 14   {'HouseNumber': 'Location not found', 'Road': ...  Location not found
# 15   {'HouseNumber': 'Location not found', 'Road': ...  Location not found
# 16   {'HouseNumber': None, 'Road': 'Newbridge Road'...                None
# 17   {'HouseNumber': None, 'Road': 'Salisbury Road'...                None
# 18   {'HouseNumber': None, 'Road': 'Newlands Road',...                None
# 19   {'HouseNumber': None, 'Road': 'Derby Road', 'T...                None
# 20   {'HouseNumber': None, 'Road': 'Lower Brownhill...                None
# 21   {'HouseNumber': 'Location not found', 'Road': ...  Location not found
# 22   {'HouseNumber': 'Location not found', 'Road': ...  Location not found
# 23   {'HouseNumber': None, 'Road': 'Luzborough Lane...                None
# 24   {'HouseNumber': 'Location not found', 'Road': ...  Location not found
# 25   {'HouseNumber': None, 'Road': None, 'Town': 'P...                None
# 26   {'HouseNumber': 'Location not found', 'Road': ...  Location not found
# 27   {'HouseNumber': 'Location not found', 'Road': ...  Location not found
# 28   {'HouseNumber': None, 'Road': 'Kiln Lane', 'To...                None
# 29   {'HouseNumber': None, 'Road': 'Alençon Link', ...                None
# ..                                                 ...                 ...
# 835  {'HouseNumber': 'Location not found', 'Road': ...  Location not found
# 836  {'HouseNumber': None, 'Road': 'A34', 'Town': '...                None
# 837  {'HouseNumber': None, 'Road': 'High Street', '...                None
# 838  {'HouseNumber': 'Location not found', 'Road': ...  Location not found
# 839  {'HouseNumber': 'Location not found', 'Road': ...  Location not found
# 840  {'HouseNumber': None, 'Road': 'Ridges View', '...                None
# 841  {'HouseNumber': 'Location not found', 'Road': ...  Location not found
# 842  {'HouseNumber': None, 'Road': 'Tennyson Road',...                None
# 843  {'HouseNumber': None, 'Road': 'Park Road', 'To...                None
# 844  {'HouseNumber': 'Location not found', 'Road': ...  Location not found
# 845  {'HouseNumber': None, 'Road': 'Main Road', 'To...                None
# 846  {'HouseNumber': None, 'Road': 'Jasmine Grove',...                None
# 847  {'HouseNumber': None, 'Road': 'Froyle Road', '...                None
# 848  {'HouseNumber': 'Location not found', 'Road': ...  Location not found
# 849  {'HouseNumber': None, 'Road': 'Basing View', '...                None
# 850  {'HouseNumber': 'Location not found', 'Road': ...  Location not found
# 851  {'HouseNumber': None, 'Road': None, 'Town': 'E...                None
# 852  {'HouseNumber': 'Location not found', 'Road': ...  Location not found
# 853  {'HouseNumber': None, 'Road': 'High Street', '...                None
# 854  {'HouseNumber': 'Location not found', 'Road': ...  Location not found
# 855  {'HouseNumber': 'Location not found', 'Road': ...  Location not found
# 856  {'HouseNumber': None, 'Road': 'Ackworth Road',...                None
# 857  {'HouseNumber': 'Location not found', 'Road': ...  Location not found
# 858  {'HouseNumber': None, 'Road': None, 'Town': 'T...                None
# 859  {'HouseNumber': None, 'Road': 'Oakridge Road',...                None
# 860  {'HouseNumber': None, 'Road': 'Cockerell Close...                None
# 861  {'HouseNumber': None, 'Road': 'Harewood Close'...                None
# 862  {'HouseNumber': None, 'Road': 'Woodbridge Road...                None
# 863  {'HouseNumber': 'Location not found', 'Road': ...  Location not found
# 864  {'HouseNumber': None, 'Road': 'Portland Terrac...                None
#
#                      Road                Town            Postcode  \
# 0      Location not found  Location not found  Location not found
# 1      Location not found  Location not found  Location not found
# 2      Location not found  Location not found  Location not found
# 3          Brownlow Close         Somers Town             PO1 4EP
# 4           Soberton Road              Havant             PO9 2EG
# 5     Shirley High Street             Shirley            SO15 3NP
# 6         Paignton Avenue             Baffins             PO3 6LL
# 7           Church Street          Whitchurch            RG28 7AD
# 8                    None       Ocean Village                None
# 9           Beaulieu Road         Denny Lodge            SO42 7YQ
# 10            Bridge Road              Romsey            SO51 8JD
# 11            London Road              Havant             PO7 7AL
# 12     Location not found  Location not found  Location not found
# 13     Location not found  Location not found  Location not found
# 14     Location not found  Location not found  Location not found
# 15     Location not found  Location not found  Location not found
# 16         Newbridge Road           Scotstoun            EH28 8QH
# 17         Salisbury Road   Sherfield English            SO51 6GR
# 18          Newlands Road              Fawley            SO45 1GD
# 19             Derby Road             Fratton             PO2 8HW
# 20   Lower Brownhill Road          Lords Hill            SO16 9LA
# 21     Location not found  Location not found  Location not found
# 22     Location not found  Location not found  Location not found
# 23        Luzborough Lane        Romsey Extra            SO51 9AA
# 24     Location not found  Location not found  Location not found
# 25                   None             Portsea                None
# 26     Location not found  Location not found  Location not found
# 27     Location not found  Location not found  Location not found
# 28              Kiln Lane         Otterbourne            SO50 6HL
# 29           Alençon Link         Basingstoke            RG21 7SB
# ..                    ...                 ...                 ...
# 835    Location not found  Location not found  Location not found
# 836                   A34          Whitchurch            RG28 7SX
# 837           High Street              Cosham             PO6 3AX
# 838    Location not found  Location not found  Location not found
# 839    Location not found  Location not found  Location not found
# 840           Ridges View            Smannell            SP11 6JF
# 841    Location not found  Location not found  Location not found
# 842         Tennyson Road           Portswood            SO17 2GW
# 843             Park Road             Gosport            PO12 2HR
# 844    Location not found  Location not found  Location not found
# 845             Main Road       Colden Common            SO21 1RS
# 846         Jasmine Grove              Havant             PO7 8BS
# 847           Froyle Road              Froyle            GU34 4BY
# 848    Location not found  Location not found  Location not found
# 849           Basing View         Basingstoke            RG21 7JD
# 850    Location not found  Location not found  Location not found
# 851                  None           Eastleigh                None
# 852    Location not found  Location not found  Location not found
# 853           High Street          North Town            GU11 1TJ
# 854    Location not found  Location not found  Location not found
# 855    Location not found  Location not found  Location not found
# 856         Ackworth Road              Hilsea             PO3 5DY
# 857    Location not found  Location not found  Location not found
# 858                  None              Tadley                None
# 859         Oakridge Road         Basingstoke            RG21 5SH
# 860       Cockerell Close             Gosport            PO13 9JF
# 861        Harewood Close           Eastleigh            SO50 4NZ
# 862       Woodbridge Road             Yateley            GU17 0BS
# 863    Location not found  Location not found  Location not found
# 864      Portland Terrace         The Polygon            SO15 1QD
#
#                     Lat                Long  PostcodeInferredFlag
# 0    Location not found  Location not found                     0
# 1    Location not found  Location not found                     0
# 2    Location not found  Location not found                     0
# 3               50.8055            -1.08463                     0
# 4               50.8633           -0.985928                     0
# 5               50.9222            -1.43333                     0
# 6               50.8128            -1.05982                     0
# 7               51.2294            -1.33968                     0
# 8               50.8956            -1.39204                     0
# 9                50.863              -1.528                     0
# 10              50.9898            -1.48759                     0
# 11              50.8763            -1.03685                     0
# 12   Location not found  Location not found                     0
# 13   Location not found  Location not found                     0
# 14   Location not found  Location not found                     0
# 15   Location not found  Location not found                     0
# 16              55.9357            -3.40625                     0
# 17              51.0029            -1.56029                     0
# 18              50.8238            -1.36985                     0
# 19               50.816            -1.08318                     0
# 20              50.9363            -1.45463                     0
# 21   Location not found  Location not found                     0
# 22   Location not found  Location not found                     0
# 23              50.9792            -1.47373                     0
# 24   Location not found  Location not found                     0
# 25              50.7955            -1.10607                     0
# 26   Location not found  Location not found                     0
# 27   Location not found  Location not found                     0
# 28              50.9994            -1.33482                     0
# 29              51.2679            -1.08474                     0
# ..                  ...                 ...                   ...
# 835  Location not found  Location not found                     0
# 836             51.2385            -1.34577                     0
# 837             50.8444            -1.06719                     0
# 838  Location not found  Location not found                     0
# 839  Location not found  Location not found                     0
# 840             51.2465            -1.45892                     0
# 841  Location not found  Location not found                     0
# 842             50.9239            -1.39277                     0
# 843             50.7856            -1.13897                     0
# 844  Location not found  Location not found                     0
# 845             51.0015             -1.3174                     0
# 846              50.873            -1.01859                     0
# 847             51.1964           -0.951451                     0
# 848  Location not found  Location not found                     0
# 849             51.2673            -1.08296                     0
# 850  Location not found  Location not found                     0
# 851             50.9689            -1.39361                     0
# 852  Location not found  Location not found                     0
# 853             51.2474           -0.755807                     0
# 854  Location not found  Location not found                     0
# 855  Location not found  Location not found                     0
# 856             50.8332            -1.06078                     0
# 857  Location not found  Location not found                     0
# 858             51.3414            -1.14468                     0
# 859             51.2772            -1.08938                     0
# 860             50.8092            -1.20101                     0
# 861             50.9821            -1.35819                     0
# 862             51.3347           -0.797265                     0
# 863  Location not found  Location not found                     0
# 864             50.9033            -1.40587                     0
#
# [865 rows x 13 columns]

# %% [markdown]
# ### Kent Geocoding

# %%
kent_query = 'select * from [initial].[Kent]'

# %%
kent_df = pd.read_sql(kent_query, cnxn)

# %%
# not run yet, will take ~45 minutes - incorrect postcodes are likely to mess up OSM 
kent_df['AddressDict'] = kent_df['Map - location shows general area of incident'].map(lambda x: get_full_address(x))

kent_df['HouseNumber'] = kent_df['AddressDict'].map(lambda x: x['HouseNumber'])
kent_df['Road'] = kent_df['AddressDict'].map(lambda x: x['Road'])
kent_df['Town'] = kent_df['AddressDict'].map(lambda x: x['Town'])
kent_df['Postcode'] = kent_df['AddressDict'].map(lambda x: x['Postcode'])
kent_df['Lat'] = kent_df['AddressDict'].map(lambda x: x['Lat'])
kent_df['Long'] = kent_df['AddressDict'].map(lambda x: x['Long'])

# %%
(kent_df.shape[0]-kent_df[kent_df['HouseNumber'] == 'Location not found'].shape[0])/kent_df.shape[0]

# %%
get_full_address('Frensham, Dockenfield and Tilford, Waverley')
# Out:
# {'HouseNumber': None,
#  'Road': 'The Reeds Road',
#  'Town': 'Tilford',
#  'Postcode': 'GU10 3BP',
#  'Lat': 51.1784402,
#  'Long': -0.778476959685393}
